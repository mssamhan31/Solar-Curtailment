# %% [markdown]
# # IMPORT MODULES & FUNCTIONS

# %%
#IMPORT PACKAGES
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt
import pytz #for timezone calculation
import math
import matplotlib.dates as md
import gc
import os
from datetime import datetime
import calendar
import seaborn as sns; sns.set()
import itertools
#import datetime
from time import gmtime, strftime
from matplotlib import cm
from IPython.display import display
#%matplotlib qt
#%matplotlib inline

#SET GLOBAL PARAMETERS
# ================== Global parameters for fonts & sizes =================
FONT_SIZE = 20
rc={'font.size': FONT_SIZE, 'axes.labelsize': FONT_SIZE, 'legend.fontsize': FONT_SIZE, 
    'axes.titlesize': FONT_SIZE, 'xtick.labelsize': FONT_SIZE, 'ytick.labelsize': FONT_SIZE}
plt.rcParams.update(**rc)
plt.rc('font', weight='bold')
 
# For label titles
fontdict={'fontsize': FONT_SIZE, 'fontweight' : 'bold'}
# can add in above dictionary: 'verticalalignment': 'baseline' 

style = 'ggplot' # choose a style from the above options
plt.style.use(style)

from solarcurtailment.energy_calculation import *
from solarcurtailment.clear_sky_day import *
from solarcurtailment.tripping_curt import *
from solarcurtailment.vvar_curt import *
from solarcurtailment.vwatt_curt import *
from solarcurtailment.polyfit import *
from solarcurtailment.file_processing import *
from solarcurtailment.data_visualization import *

#Remove unnecessary warning
pd.options.mode.chained_assignment = None  # default='warn'
np.warnings.filterwarnings('ignore')

#class instantiation
file_processing = FileProcessing()
clear_sky_day = ClearSkyDay()
data_visualization = DataVisualization()
energy_calculation = EnergyCalculation()
tripping_curt = TrippingCurt()
polyfit_f = Polyfit()
vvar_curt = VVarCurt()
vwatt_curt = VWattCurt()

#from FileProcessing 
def input_monthly_files(file_path, data_date_idx):
    """Open time-series D-PV data and ghi data of a certain month. Only compatible for SoLA data format.

    Args:
        file_path (str): The file location of the data
        data_date_idx (str): The month of the files in format 'YYYYMM' eg '201907'

    Returns:
        data (df): the opened & cleaned time-series D-PV data
        ghi (df): the opened & cleaned ghi data
        data_ori (df): the opened & unmodified time-series D-PV data
        ghi_ori (df): the opened & unmodified ghi data
    """
    
    data_path = file_path + r"/processed_unsw_" + data_date_idx + '_data_raw.csv'
    data_ori = pd.read_csv(data_path)
    data = data_ori.set_index('utc_tstamp')

    # Convert timestamp to local Adelaide time
    data.index = pd.to_datetime(data.index) # convert index from object type to datetime
    Adelaide_local_time = pytz.timezone('Australia/Adelaide')
    data.index = data.index.tz_localize(pytz.utc).tz_convert(Adelaide_local_time) # convert utc to local adelaide time
    data.index.rename('Timestamp', inplace = True)

    # Load GHI data
    ghi_date_idx = data_date_idx[0:4] + '_' + data_date_idx[4:]
    ghi_path = file_path + r"/sl_023034_" + ghi_date_idx +'.txt'
    ghi = pd.read_csv (ghi_path) 
    ghi_ori = ghi.copy()

    ghi['timestamp'] = pd.to_datetime(pd.DataFrame ({'year' : ghi['Year Month Day Hours Minutes in YYYY'].values, 
                                                    'month' : ghi['MM'], 
                                                    'day' : ghi['DD'], 
                                                   'hour' : ghi['HH24'], 
                                                   'minute' : ghi['MI format in Local standard time']}))
    ghi.set_index('timestamp', inplace = True)
    # Deal with the space characters (ghi is in object/string form at the moment)
    ghi['Mean global irradiance (over 1 minute) in W/sq m'] = [float(ghi_t) if ghi_t.count(' ')<= 3 else np.nan for ghi_t in ghi['Mean global irradiance (over 1 minute) in W/sq m']]
    
    return data, ghi, data_ori, ghi_ori
# Out:
# C:\Users\samha\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # CHECK ALL DAYS
# Find list of all dates which data are available

# %%
def create_date_list(year, month, num_of_days):
    """Create a list of date as str for certain month and year.

    Args:
        year (str): year
        month (str): month
        num_of_days (int): number of days for a certain month and year. 

    Returns:
        date_list (list): list of date as str
    """
    
    date_list = []
    
    for i in range(1, 10):
        date_list.append(year + '-' + month + '-0'  + str(i))
    for i in range(10, num_of_days + 1):
        date_list.append(year + '-' + month + '-'  + str(i))
    
    return date_list

# %%
datelist_201907 = create_date_list('2019', '07', 31)
datelist_201908 = create_date_list('2019', '08', 31)
datelist_201909 = create_date_list('2019', '09', 30)
datelist_201910 = create_date_list('2019', '10', 31)
datelist_201911 = create_date_list('2019', '11', 30)
datelist_201912 = create_date_list('2019', '12', 31)
datelist_202001 = create_date_list('2020', '01', 31)
datelist_202002 = create_date_list('2020', '02', 29)
datelist_202003 = create_date_list('2020', '03', 31)
datelist_202004 = create_date_list('2020', '04', 30)


date_list = datelist_201907 + datelist_201908 + datelist_201909 + datelist_201910 + datelist_201911 + datelist_201912 + datelist_202001 + datelist_202002 + datelist_202003 + datelist_202004

# %% [markdown]
# # CLEAR SKY DAYS LIST

# %%
csd_201907 = ['2019-07-09', '2019-07-19', '2019-07-20']
csd_201908 = ['2019-08-05', '2019-08-14', '2019-08-23', '2019-08-26', '2019-08-30']
csd_201909 = ['2019-09-12', '2019-09-17', '2019-09-18', '2019-09-26', '2019-09-29', '2019-09-30']
csd_201910 = ['2019-10-01', '2019-10-02', '2019-10-03', '2019-10-29']
csd_201911 = ['2019-11-18', '2019-11-27']
csd_201912 = ['2019-12-16', '2019-12-19', '2019-12-25', '2019-12-28']
csd_202001 = ['2020-01-01', '2020-01-02', '2020-01-06', '2020-01-07', '2020-01-08', '2020-01-12', '2020-01-13', '2020-01-14', '2020-01-17', '2020-01-29', '2020-01-30']
csd_202002 = ['2020-02-04', '2020-02-05', '2020-02-06', '2020-02-10', '2020-02-11', '2020-02-13', '2020-02-22', '2020-02-23']
csd_202003 = ['2020-03-03', '2020-03-08', '2020-03-10', '2020-03-14', '2020-03-15', '2020-03-25', '2020-03-26']
csd_202004 = ['2020-04-08', '2020-04-09', '2020-04-13', '2020-04-24']

csd_list = csd_201907 + csd_201908 + csd_201909 + csd_201910 + csd_201911 + csd_201912 + csd_202001 + csd_202002 + csd_202003 + csd_202004

# %% [markdown]
# # INPUT ALL MONTHLY DATA & GENERAL FILES

# %%
#file_path = r"/Users/samhan/Downloads/data" #for running in Samhan's laptop
file_path = r"C:\Users\samha\Documents\CANVAS\data" #for running in TETB CEEM09 computer

# %%
month_list = ['201907', '201908', '201909', '201910', '201911', '201912', '202001', '202002', '202003', '202004']
data = {}
data_ori = {}
ghi = {}
ghi_ori = {}
for month in month_list:
    print('processing {} ...'.format(month))
    data[month], ghi[month], data_ori[month], ghi_ori[month] = input_monthly_files(file_path, month)
    data[month]['date'] = data[month].index.date
    
site_details, unique_cids= file_processing.input_general_files(file_path)
# Out:
# processing 201909 ...
# processing 201910 ...
# processing 201911 ...
# processing 201912 ...
# processing 202001 ...
# processing 202002 ...
# processing 202003 ...
# processing 202004 ...

# %%
#DELETE LATER
month_list = ['201907', '201908']
for month in month_list:
    print('processing {} ...'.format(month))
    data[month], ghi[month], data_ori[month], ghi_ori[month] = input_monthly_files(file_path, month)
    data[month]['date'] = data[month].index.date
# Out:
# processing 201907 ...
# processing 201908 ...

# %% [markdown]
# # DIVIDE THE COMPUTATION INTO 5 BATCH, 100 SITES PER BATCH

# %%
c_id_batch_1 = unique_cids['c_id'][:100]
c_id_batch_2 = unique_cids['c_id'][100:200]
c_id_batch_3 = unique_cids['c_id'][200:300]
c_id_batch_4 = unique_cids['c_id'][300:400]
c_id_batch_5 = unique_cids['c_id'][400:500]

# %% [markdown]
# # LOOP FOR 10 MONTHS FOR CSD

# %% [markdown]
# # BATCH 1

# %%
batch = 1

# %%
summary = pd.DataFrame()
date_not_analyzed = []
date_successfully_analyzed = []
site_number = 1

for c_id in c_id_batch_1:
    print('Analyzing site {} of 100 sites, c_id {}'.format(site_number, c_id))
    site_number += 1
    
    last_month_analyzed = 201907
    last_cid_analyzed = 0
    count_curtailment = 0
    total_energy_generation = 0
    total_tripping_curtailment = 0
    for date in csd_list: 
#         print('Analyzing c_id {} date {} ...'.format(c_id, date))
        
        #filter D-PV time series data
        date_dt = dt.datetime.strptime(date, '%Y-%m-%d').date()
        month_analyzed = date[:4] + date [5:7]
#         print('Analyzing c_id {} month {} ...'.format(c_id, month_analyzed))
        
        if not month_analyzed == last_month_analyzed:
            site_id_filter = data[month_analyzed]['c_id'] == c_id
            data_certain_site = data[month_analyzed].loc[site_id_filter]
            last_month_analyzed = month_analyzed
            
        date_filter = data_certain_site['date'] == date_dt
        data_analyzed = data_certain_site.loc[date_filter]
        data_analyzed = data_analyzed.sort_index(ascending=True)

        #check tripping curtailment
        ac_cap = int(site_details.loc[site_details['c_id'] == c_id, 'ac_cap_w'])
        size_is_ok = file_processing.check_data_size(data_analyzed, ac_cap)
        
        if not size_is_ok:
#             print('Cannot analyze {} site on {} due to incomplete data.'.format(c_id, date))
            date_not_analyzed.append(date)
#             data_analyzed['power'].plot()
#             plt.show()
        else:
            date_successfully_analyzed.append(date)
            data_site, ac_cap, dc_cap, EFF_SYSTEM, inverter = vvar_curt.site_organize(c_id, site_details, data_analyzed, unique_cids)
            data_site = file_processing.resample_in_minute(data_site)
            
            if date in csd_list:
                is_clear_sky_day = True
            else:
                is_clear_sky_day = False
            
            tripping_response, tripping_curt_energy, estimation_method, data_site = tripping_curt.check_tripping_curtailment(is_clear_sky_day, c_id, data_site, unique_cids, ac_cap, site_details, date)    
            energy_generated, data_site = energy_calculation.check_energy_generated(data_site, date, is_clear_sky_day, tripping_curt_energy)
            
            total_energy_generation += energy_generated
            
            if tripping_curt_energy > 0:
                count_curtailment += 1
                total_tripping_curtailment += tripping_curt_energy
    
    #summarize result
    c_id_summary = pd.DataFrame({
            'c_id' : [c_id],
            'total_energy_generation (kWh)' : [total_energy_generation],
            'total_tripping_curtailment (kWh)' : [total_tripping_curtailment],
            'count curtailment (days)' : [count_curtailment],
            'total days (days)' : [len(csd_list)]
        })
    
    summary = pd.concat([summary, c_id_summary])

summary.to_csv(file_path + r'/tripping_csd_{}.csv'.format(batch), index = False)
# Out:
# Analyzing site 1 of 100 sites, c_id 1700492033
# Analyzing site 2 of 100 sites, c_id 1146549788
# Analyzing site 3 of 100 sites, c_id 1027250881
# Analyzing site 4 of 100 sites, c_id 389622988
# Analyzing site 5 of 100 sites, c_id 1363592770
# Analyzing site 6 of 100 sites, c_id 1814154495
# Analyzing site 7 of 100 sites, c_id 920290771
# Analyzing site 8 of 100 sites, c_id 825500746
# Analyzing site 9 of 100 sites, c_id 1864193631
# Analyzing site 10 of 100 sites, c_id 1173628499
# Analyzing site 11 of 100 sites, c_id 684163813
# Analyzing site 12 of 100 sites, c_id 440658205
# Analyzing site 13 of 100 sites, c_id 594232181
# Analyzing site 14 of 100 sites, c_id 1288089120
# Analyzing site 15 of 100 sites, c_id 2084803628
# Analyzing site 16 of 100 sites, c_id 1561543809
# Analyzing site 17 of 100 sites, c_id 1648066113
# Analyzing site 18 of 100 sites, c_id 1326376829
# Analyzing site 19 of 100 sites, c_id 960184009
# Analyzing site 20 of 100 sites, c_id 1276618490
# Analyzing site 21 of 100 sites, c_id 948674318
# Analyzing site 22 of 100 sites, c_id 198317149
# Analyzing site 23 of 100 sites, c_id 356902470
# Analyzing site 24 of 100 sites, c_id 347781920
# Analyzing site 25 of 100 sites, c_id 1025629477
# Analyzing site 26 of 100 sites, c_id 418705795
# Analyzing site 27 of 100 sites, c_id 1839454790
# Analyzing site 28 of 100 sites, c_id 633265858
# Analyzing site 29 of 100 sites, c_id 12367274
# Analyzing site 30 of 100 sites, c_id 655226065
# Analyzing site 31 of 100 sites, c_id 1460435438
# Analyzing site 32 of 100 sites, c_id 502299900
# Analyzing site 33 of 100 sites, c_id 1487396633
# Analyzing site 34 of 100 sites, c_id 208735378
# Analyzing site 35 of 100 sites, c_id 1507813811
# Analyzing site 36 of 100 sites, c_id 441066515
# Analyzing site 37 of 100 sites, c_id 2102460517
# Analyzing site 38 of 100 sites, c_id 1026364810
# Analyzing site 39 of 100 sites, c_id 1817947752
# Analyzing site 40 of 100 sites, c_id 108093008
# Analyzing site 41 of 100 sites, c_id 635240510
# Analyzing site 42 of 100 sites, c_id 533614327
# Analyzing site 43 of 100 sites, c_id 447392482
# Analyzing site 44 of 100 sites, c_id 577971316
# Analyzing site 45 of 100 sites, c_id 869224242
# Analyzing site 46 of 100 sites, c_id 1557532993
# Analyzing site 47 of 100 sites, c_id 243473926
# Analyzing site 48 of 100 sites, c_id 495557193
# Analyzing site 49 of 100 sites, c_id 1782897736
# Analyzing site 50 of 100 sites, c_id 1825743529
# Analyzing site 51 of 100 sites, c_id 834632262
# Analyzing site 52 of 100 sites, c_id 1709888896
# Analyzing site 53 of 100 sites, c_id 1392712752
# Analyzing site 54 of 100 sites, c_id 1963524104
# Analyzing site 55 of 100 sites, c_id 677022387
# Analyzing site 56 of 100 sites, c_id 810477632
# Analyzing site 57 of 100 sites, c_id 687183866
# Analyzing site 58 of 100 sites, c_id 1264543056
# Analyzing site 59 of 100 sites, c_id 294943318
# Analyzing site 60 of 100 sites, c_id 939510347
# Analyzing site 61 of 100 sites, c_id 1723756348
# Analyzing site 62 of 100 sites, c_id 538085926
# Analyzing site 63 of 100 sites, c_id 1695134492
# Analyzing site 64 of 100 sites, c_id 1917897599
# Analyzing site 65 of 100 sites, c_id 1149850021
# Analyzing site 66 of 100 sites, c_id 726512226
# Analyzing site 67 of 100 sites, c_id 63789504
# Analyzing site 68 of 100 sites, c_id 1295562498
# Analyzing site 69 of 100 sites, c_id 1542012877
# Analyzing site 70 of 100 sites, c_id 680721840
# Analyzing site 71 of 100 sites, c_id 2131332818
# Analyzing site 72 of 100 sites, c_id 345636960
# Analyzing site 73 of 100 sites, c_id 1803391106
# Analyzing site 74 of 100 sites, c_id 67797136
# Analyzing site 75 of 100 sites, c_id 1834624576
# Analyzing site 76 of 100 sites, c_id 1732727321
# Analyzing site 77 of 100 sites, c_id 868206338
# Analyzing site 78 of 100 sites, c_id 315545704
# Analyzing site 79 of 100 sites, c_id 1391211810
# Analyzing site 80 of 100 sites, c_id 1340845257
# Analyzing site 81 of 100 sites, c_id 360739036
# Analyzing site 82 of 100 sites, c_id 849191343
# Analyzing site 83 of 100 sites, c_id 1330053407
# Analyzing site 84 of 100 sites, c_id 883238613
# Analyzing site 85 of 100 sites, c_id 851913431
# Analyzing site 86 of 100 sites, c_id 659251981
# Analyzing site 87 of 100 sites, c_id 1033215718
# Analyzing site 88 of 100 sites, c_id 358283166
# Analyzing site 89 of 100 sites, c_id 475339127
# Analyzing site 90 of 100 sites, c_id 1398093534
# Analyzing site 91 of 100 sites, c_id 498672601
# Analyzing site 92 of 100 sites, c_id 1738680151
# Analyzing site 93 of 100 sites, c_id 1823883062
# Analyzing site 94 of 100 sites, c_id 492423664
# Analyzing site 95 of 100 sites, c_id 1911428877
# Analyzing site 96 of 100 sites, c_id 1366939490
# Analyzing site 97 of 100 sites, c_id 1007132094
# Analyzing site 98 of 100 sites, c_id 636891105
# Analyzing site 99 of 100 sites, c_id 140917090
# Analyzing site 100 of 100 sites, c_id 1994239929

# %% [markdown]
# # BATCH 2

# %%
batch = 2

# %%
summary = pd.DataFrame()
date_not_analyzed = []
date_successfully_analyzed = []
site_number = 1

for c_id in c_id_batch_2:
    print('Analyzing site {} of 100 sites, c_id {}'.format(site_number, c_id))
    site_number += 1
    
    last_month_analyzed = 201907
    last_cid_analyzed = 0
    count_curtailment = 0
    total_energy_generation = 0
    total_tripping_curtailment = 0
    for date in csd_list: 
#         print('Analyzing c_id {} date {} ...'.format(c_id, date))
        
        #filter D-PV time series data
        date_dt = dt.datetime.strptime(date, '%Y-%m-%d').date()
        month_analyzed = date[:4] + date [5:7]
#         print('Analyzing c_id {} month {} ...'.format(c_id, month_analyzed))
        
        if not month_analyzed == last_month_analyzed:
            site_id_filter = data[month_analyzed]['c_id'] == c_id
            data_certain_site = data[month_analyzed].loc[site_id_filter]
            last_month_analyzed = month_analyzed
            
        date_filter = data_certain_site['date'] == date_dt
        data_analyzed = data_certain_site.loc[date_filter]
        data_analyzed = data_analyzed.sort_index(ascending=True)

        #check tripping curtailment
        ac_cap = int(site_details.loc[site_details['c_id'] == c_id, 'ac_cap_w'])
        size_is_ok = file_processing.check_data_size(data_analyzed, ac_cap)
        
        if not size_is_ok:
#             print('Cannot analyze {} site on {} due to incomplete data.'.format(c_id, date))
            date_not_analyzed.append(date)
#             data_analyzed['power'].plot()
#             plt.show()
        else:
            date_successfully_analyzed.append(date)
            data_site, ac_cap, dc_cap, EFF_SYSTEM, inverter = vvar_curt.site_organize(c_id, site_details, data_analyzed, unique_cids)
            data_site = file_processing.resample_in_minute(data_site)
            
            if date in csd_list:
                is_clear_sky_day = True
            else:
                is_clear_sky_day = False
            
            tripping_response, tripping_curt_energy, estimation_method, data_site = tripping_curt.check_tripping_curtailment(is_clear_sky_day, c_id, data_site, unique_cids, ac_cap, site_details, date)    
            energy_generated, data_site = energy_calculation.check_energy_generated(data_site, date, is_clear_sky_day, tripping_curt_energy)
            
            total_energy_generation += energy_generated
            
            if tripping_curt_energy > 0:
                count_curtailment += 1
                total_tripping_curtailment += tripping_curt_energy
    
    #summarize result
    c_id_summary = pd.DataFrame({
            'c_id' : [c_id],
            'total_energy_generation (kWh)' : [total_energy_generation],
            'total_tripping_curtailment (kWh)' : [total_tripping_curtailment],
            'count curtailment (days)' : [count_curtailment],
            'total days (days)' : [len(csd_list)]
        })
    
    summary = pd.concat([summary, c_id_summary])

summary.to_csv(file_path + r'/tripping_csd_{}.csv'.format(batch), index = False)
# Out:
# Analyzing site 1 of 100 sites, c_id 1765463917
# Analyzing site 2 of 100 sites, c_id 362641176
# Analyzing site 3 of 100 sites, c_id 501296684
# Analyzing site 4 of 100 sites, c_id 728603657
# Analyzing site 5 of 100 sites, c_id 1754502986
# Analyzing site 6 of 100 sites, c_id 671978489
# Analyzing site 7 of 100 sites, c_id 977227615
# Analyzing site 8 of 100 sites, c_id 576609445
# KeyboardInterrupt

# %% [markdown]
# # BATCH 3

# %%
batch = 3

# %%
summary = pd.DataFrame()
date_not_analyzed = []
date_successfully_analyzed = []
site_number = 1

for c_id in c_id_batch_3: 
    print('Analyzing site {} of 100 sites, c_id {}'.format(site_number, c_id))
    site_number += 1
    
    last_month_analyzed = 201907
    last_cid_analyzed = 0
    count_curtailment = 0
    total_energy_generation = 0
    total_tripping_curtailment = 0
    for date in csd_list: 
#         print('Analyzing c_id {} date {} ...'.format(c_id, date))
        
        #filter D-PV time series data
        date_dt = dt.datetime.strptime(date, '%Y-%m-%d').date()
        month_analyzed = date[:4] + date [5:7]
#         print('Analyzing c_id {} month {} ...'.format(c_id, month_analyzed))
        
        if not month_analyzed == last_month_analyzed:
            site_id_filter = data[month_analyzed]['c_id'] == c_id
            data_certain_site = data[month_analyzed].loc[site_id_filter]
            last_month_analyzed = month_analyzed
            
        date_filter = data_certain_site['date'] == date_dt
        data_analyzed = data_certain_site.loc[date_filter]
        data_analyzed = data_analyzed.sort_index(ascending=True)

        #check tripping curtailment
        ac_cap = int(site_details.loc[site_details['c_id'] == c_id, 'ac_cap_w'])
        size_is_ok = file_processing.check_data_size(data_analyzed, ac_cap)
        
        if not size_is_ok:
#             print('Cannot analyze {} site on {} due to incomplete data.'.format(c_id, date))
            date_not_analyzed.append(date)
#             data_analyzed['power'].plot()
#             plt.show()
        else:
            date_successfully_analyzed.append(date)
            data_site, ac_cap, dc_cap, EFF_SYSTEM, inverter = vvar_curt.site_organize(c_id, site_details, data_analyzed, unique_cids)
            data_site = file_processing.resample_in_minute(data_site)
            
            if date in csd_list:
                is_clear_sky_day = True
            else:
                is_clear_sky_day = False
            
            tripping_response, tripping_curt_energy, estimation_method, data_site = tripping_curt.check_tripping_curtailment(is_clear_sky_day, c_id, data_site, unique_cids, ac_cap, site_details, date)    
            energy_generated, data_site = energy_calculation.check_energy_generated(data_site, date, is_clear_sky_day, tripping_curt_energy)
            
            total_energy_generation += energy_generated
            
            if tripping_curt_energy > 0:
                count_curtailment += 1
                total_tripping_curtailment += tripping_curt_energy
    
    #summarize result
    c_id_summary = pd.DataFrame({
            'c_id' : [c_id],
            'total_energy_generation (kWh)' : [total_energy_generation],
            'total_tripping_curtailment (kWh)' : [total_tripping_curtailment],
            'count curtailment (days)' : [count_curtailment],
            'total days (days)' : [len(csd_list)]
        })
    
    summary = pd.concat([summary, c_id_summary])

summary.to_csv(file_path + r'/tripping_csd_{}.csv'.format(batch), index = False)

# %% [markdown]
# # BATCH 4

# %%
batch = 4

# %%
summary = pd.DataFrame()
date_not_analyzed = []
date_successfully_analyzed = []
site_number = 1

for c_id in c_id_batch_4: 
    print('Analyzing site {} of 100 sites, c_id {}'.format(site_number, c_id))
    site_number += 1
    
    last_month_analyzed = 201907
    last_cid_analyzed = 0
    count_curtailment = 0
    total_energy_generation = 0
    total_tripping_curtailment = 0
    for date in csd_list: 
#         print('Analyzing c_id {} date {} ...'.format(c_id, date))
        
        #filter D-PV time series data
        date_dt = dt.datetime.strptime(date, '%Y-%m-%d').date()
        month_analyzed = date[:4] + date [5:7]
#         print('Analyzing c_id {} month {} ...'.format(c_id, month_analyzed))
        
        if not month_analyzed == last_month_analyzed:
            site_id_filter = data[month_analyzed]['c_id'] == c_id
            data_certain_site = data[month_analyzed].loc[site_id_filter]
            last_month_analyzed = month_analyzed
            
        date_filter = data_certain_site['date'] == date_dt
        data_analyzed = data_certain_site.loc[date_filter]
        data_analyzed = data_analyzed.sort_index(ascending=True)

        #check tripping curtailment
        ac_cap = int(site_details.loc[site_details['c_id'] == c_id, 'ac_cap_w'])
        size_is_ok = file_processing.check_data_size(data_analyzed, ac_cap)
        
        if not size_is_ok:
#             print('Cannot analyze {} site on {} due to incomplete data.'.format(c_id, date))
            date_not_analyzed.append(date)
#             data_analyzed['power'].plot()
#             plt.show()
        else:
            date_successfully_analyzed.append(date)
            data_site, ac_cap, dc_cap, EFF_SYSTEM, inverter = vvar_curt.site_organize(c_id, site_details, data_analyzed, unique_cids)
            data_site = file_processing.resample_in_minute(data_site)
            
            if date in csd_list:
                is_clear_sky_day = True
            else:
                is_clear_sky_day = False
            
            tripping_response, tripping_curt_energy, estimation_method, data_site = tripping_curt.check_tripping_curtailment(is_clear_sky_day, c_id, data_site, unique_cids, ac_cap, site_details, date)    
            energy_generated, data_site = energy_calculation.check_energy_generated(data_site, date, is_clear_sky_day, tripping_curt_energy)
            
            total_energy_generation += energy_generated
            
            if tripping_curt_energy > 0:
                count_curtailment += 1
                total_tripping_curtailment += tripping_curt_energy
    
    #summarize result
    c_id_summary = pd.DataFrame({
            'c_id' : [c_id],
            'total_energy_generation (kWh)' : [total_energy_generation],
            'total_tripping_curtailment (kWh)' : [total_tripping_curtailment],
            'count curtailment (days)' : [count_curtailment],
            'total days (days)' : [len(csd_list)]
        })
    
    summary = pd.concat([summary, c_id_summary])

summary.to_csv(file_path + r'/tripping_csd_{}.csv'.format(batch), index = False)

# %% [markdown]
# # BATCH 5

# %%
batch = 5

# %%
summary = pd.DataFrame()
date_not_analyzed = []
date_successfully_analyzed = []
site_number = 1

for c_id in c_id_batch_5: 
    print('Analyzing site {} of 100 sites, c_id {}'.format(site_number, c_id))
    site_number += 1
    
    last_month_analyzed = 201907
    last_cid_analyzed = 0
    count_curtailment = 0
    total_energy_generation = 0
    total_tripping_curtailment = 0
    for date in csd_list: 
#         print('Analyzing c_id {} date {} ...'.format(c_id, date))
        
        #filter D-PV time series data
        date_dt = dt.datetime.strptime(date, '%Y-%m-%d').date()
        month_analyzed = date[:4] + date [5:7]
#         print('Analyzing c_id {} month {} ...'.format(c_id, month_analyzed))
        
        if not month_analyzed == last_month_analyzed:
            site_id_filter = data[month_analyzed]['c_id'] == c_id
            data_certain_site = data[month_analyzed].loc[site_id_filter]
            last_month_analyzed = month_analyzed
            
        date_filter = data_certain_site['date'] == date_dt
        data_analyzed = data_certain_site.loc[date_filter]
        data_analyzed = data_analyzed.sort_index(ascending=True)

        #check tripping curtailment
        ac_cap = int(site_details.loc[site_details['c_id'] == c_id, 'ac_cap_w'])
        size_is_ok = file_processing.check_data_size(data_analyzed, ac_cap)
        
        if not size_is_ok:
#             print('Cannot analyze {} site on {} due to incomplete data.'.format(c_id, date))
            date_not_analyzed.append(date)
#             data_analyzed['power'].plot()
#             plt.show()
        else:
            date_successfully_analyzed.append(date)
            data_site, ac_cap, dc_cap, EFF_SYSTEM, inverter = vvar_curt.site_organize(c_id, site_details, data_analyzed, unique_cids)
            data_site = file_processing.resample_in_minute(data_site)
            
            if date in csd_list:
                is_clear_sky_day = True
            else:
                is_clear_sky_day = False
            
            tripping_response, tripping_curt_energy, estimation_method, data_site = tripping_curt.check_tripping_curtailment(is_clear_sky_day, c_id, data_site, unique_cids, ac_cap, site_details, date)    
            energy_generated, data_site = energy_calculation.check_energy_generated(data_site, date, is_clear_sky_day, tripping_curt_energy)
            
            total_energy_generation += energy_generated
            
            if tripping_curt_energy > 0:
                count_curtailment += 1
                total_tripping_curtailment += tripping_curt_energy
    
    #summarize result
    c_id_summary = pd.DataFrame({
            'c_id' : [c_id],
            'total_energy_generation (kWh)' : [total_energy_generation],
            'total_tripping_curtailment (kWh)' : [total_tripping_curtailment],
            'count curtailment (days)' : [count_curtailment],
            'total days (days)' : [len(csd_list)]
        })
    
    summary = pd.concat([summary, c_id_summary])

summary.to_csv(file_path + r'/tripping_csd_{}.csv'.format(batch), index = False)

# %% [markdown]
# # LOOP FOR 10 MONTHS FOR ALL DAYS

# %% [markdown]
# # BATCH 1

# %%
batch = 1

# %%
summary = pd.DataFrame()
date_not_analyzed = []
date_successfully_analyzed = []
site_number = 1

for c_id in c_id_batch_1: 
    print('Analyzing site {} of 100 sites, c_id {}'.format(site_number, c_id))
    site_number += 1
    
    last_month_analyzed = 201907
    last_cid_analyzed = 0
    count_curtailment = 0
    total_energy_generation = 0
    total_tripping_curtailment = 0
    for date in date_list: 
#         print('Analyzing c_id {} date {} ...'.format(c_id, date))
        
        #filter D-PV time series data
        date_dt = dt.datetime.strptime(date, '%Y-%m-%d').date()
        month_analyzed = date[:4] + date [5:7]
#         print('Analyzing c_id {} month {} ...'.format(c_id, month_analyzed))
        
        if not month_analyzed == last_month_analyzed:
            site_id_filter = data[month_analyzed]['c_id'] == c_id
            data_certain_site = data[month_analyzed].loc[site_id_filter]
            last_month_analyzed = month_analyzed
            
        date_filter = data_certain_site['date'] == date_dt
        data_analyzed = data_certain_site.loc[date_filter]
        data_analyzed = data_analyzed.sort_index(ascending=True)

        #check tripping curtailment
        ac_cap = int(site_details.loc[site_details['c_id'] == c_id, 'ac_cap_w'])
        size_is_ok = file_processing.check_data_size(data_analyzed, ac_cap)
        
        if not size_is_ok:
#             print('Cannot analyze {} site on {} due to incomplete data.'.format(c_id, date))
            date_not_analyzed.append(date)
#             data_analyzed['power'].plot()
#             plt.show()
        else:
            date_successfully_analyzed.append(date)
            data_site, ac_cap, dc_cap, EFF_SYSTEM, inverter = vvar_curt.site_organize(c_id, site_details, data_analyzed, unique_cids)
            data_site = file_processing.resample_in_minute(data_site)
            
            if date in csd_list:
                is_clear_sky_day = True
            else:
                is_clear_sky_day = False
            
            tripping_response, tripping_curt_energy, estimation_method, data_site = tripping_curt.check_tripping_curtailment(is_clear_sky_day, c_id, data_site, unique_cids, ac_cap, site_details, date)    
            energy_generated, data_site = energy_calculation.check_energy_generated(data_site, date, is_clear_sky_day, tripping_curt_energy)
            
            total_energy_generation += energy_generated
            
            if tripping_curt_energy > 0:
                count_curtailment += 1
                total_tripping_curtailment += tripping_curt_energy
    
    #summarize result
    c_id_summary = pd.DataFrame({
            'c_id' : [c_id],
            'total_energy_generation (kWh)' : [total_energy_generation],
            'total_tripping_curtailment (kWh)' : [total_tripping_curtailment],
            'count curtailment (days)' : [count_curtailment],
            'total days (days)' : [len(date_list)]
        })
    
    summary = pd.concat([summary, c_id_summary])

summary.to_csv(file_path + r'/tripping_alldays_{}.csv'.format(batch), index = False)
# Out:
# Analyzing site 1 of 100 sites, c_id 1700492033
# Analyzing site 2 of 100 sites, c_id 1146549788
# Analyzing site 3 of 100 sites, c_id 1027250881
# Analyzing site 4 of 100 sites, c_id 389622988
# Analyzing site 5 of 100 sites, c_id 1363592770
# Analyzing site 6 of 100 sites, c_id 1814154495
# Analyzing site 7 of 100 sites, c_id 920290771
# Analyzing site 8 of 100 sites, c_id 825500746
# Analyzing site 9 of 100 sites, c_id 1864193631
# Analyzing site 10 of 100 sites, c_id 1173628499
# Analyzing site 11 of 100 sites, c_id 684163813
# Analyzing site 12 of 100 sites, c_id 440658205
# Analyzing site 13 of 100 sites, c_id 594232181
# Analyzing site 14 of 100 sites, c_id 1288089120
# Analyzing site 15 of 100 sites, c_id 2084803628
# Analyzing site 16 of 100 sites, c_id 1561543809
# Analyzing site 17 of 100 sites, c_id 1648066113
# Analyzing site 18 of 100 sites, c_id 1326376829
# Analyzing site 19 of 100 sites, c_id 960184009
# Analyzing site 20 of 100 sites, c_id 1276618490
# Analyzing site 21 of 100 sites, c_id 948674318
# Analyzing site 22 of 100 sites, c_id 198317149
# Analyzing site 23 of 100 sites, c_id 356902470
# Analyzing site 24 of 100 sites, c_id 347781920
# Analyzing site 25 of 100 sites, c_id 1025629477
# Analyzing site 26 of 100 sites, c_id 418705795
# Analyzing site 27 of 100 sites, c_id 1839454790
# Analyzing site 28 of 100 sites, c_id 633265858
# Analyzing site 29 of 100 sites, c_id 12367274
# Analyzing site 30 of 100 sites, c_id 655226065
# Analyzing site 31 of 100 sites, c_id 1460435438
# Analyzing site 32 of 100 sites, c_id 502299900
# Analyzing site 33 of 100 sites, c_id 1487396633
# Analyzing site 34 of 100 sites, c_id 208735378
# Analyzing site 35 of 100 sites, c_id 1507813811
# Analyzing site 36 of 100 sites, c_id 441066515
# Analyzing site 37 of 100 sites, c_id 2102460517
# Analyzing site 38 of 100 sites, c_id 1026364810
# Analyzing site 39 of 100 sites, c_id 1817947752
# Analyzing site 40 of 100 sites, c_id 108093008
# Analyzing site 41 of 100 sites, c_id 635240510
# Analyzing site 42 of 100 sites, c_id 533614327
# Analyzing site 43 of 100 sites, c_id 447392482
# Analyzing site 44 of 100 sites, c_id 577971316
# Analyzing site 45 of 100 sites, c_id 869224242
# Analyzing site 46 of 100 sites, c_id 1557532993
# Analyzing site 47 of 100 sites, c_id 243473926
# Analyzing site 48 of 100 sites, c_id 495557193
# Analyzing site 49 of 100 sites, c_id 1782897736
# Analyzing site 50 of 100 sites, c_id 1825743529
# Analyzing site 51 of 100 sites, c_id 834632262
# Analyzing site 52 of 100 sites, c_id 1709888896
# Analyzing site 53 of 100 sites, c_id 1392712752
# Analyzing site 54 of 100 sites, c_id 1963524104
# Analyzing site 55 of 100 sites, c_id 677022387
# Analyzing site 56 of 100 sites, c_id 810477632
# Analyzing site 57 of 100 sites, c_id 687183866
# Analyzing site 58 of 100 sites, c_id 1264543056
# Analyzing site 59 of 100 sites, c_id 294943318
# Analyzing site 60 of 100 sites, c_id 939510347
# Analyzing site 61 of 100 sites, c_id 1723756348
# Analyzing site 62 of 100 sites, c_id 538085926
# Analyzing site 63 of 100 sites, c_id 1695134492
# Analyzing site 64 of 100 sites, c_id 1917897599
# Analyzing site 65 of 100 sites, c_id 1149850021
# Analyzing site 66 of 100 sites, c_id 726512226
# Analyzing site 67 of 100 sites, c_id 63789504
# Analyzing site 68 of 100 sites, c_id 1295562498
# Analyzing site 69 of 100 sites, c_id 1542012877
# Analyzing site 70 of 100 sites, c_id 680721840
# Analyzing site 71 of 100 sites, c_id 2131332818
# Analyzing site 72 of 100 sites, c_id 345636960
# Analyzing site 73 of 100 sites, c_id 1803391106
# Analyzing site 74 of 100 sites, c_id 67797136
# Analyzing site 75 of 100 sites, c_id 1834624576
# Analyzing site 76 of 100 sites, c_id 1732727321
# Analyzing site 77 of 100 sites, c_id 868206338
# Analyzing site 78 of 100 sites, c_id 315545704
# Analyzing site 79 of 100 sites, c_id 1391211810
# Analyzing site 80 of 100 sites, c_id 1340845257
# Analyzing site 81 of 100 sites, c_id 360739036
# Analyzing site 82 of 100 sites, c_id 849191343
# Analyzing site 83 of 100 sites, c_id 1330053407
# Analyzing site 84 of 100 sites, c_id 883238613
# Analyzing site 85 of 100 sites, c_id 851913431
# Analyzing site 86 of 100 sites, c_id 659251981
# Analyzing site 87 of 100 sites, c_id 1033215718
# Analyzing site 88 of 100 sites, c_id 358283166
# Analyzing site 89 of 100 sites, c_id 475339127
# Analyzing site 90 of 100 sites, c_id 1398093534
# Analyzing site 91 of 100 sites, c_id 498672601
# Analyzing site 92 of 100 sites, c_id 1738680151
# Analyzing site 93 of 100 sites, c_id 1823883062
# Analyzing site 94 of 100 sites, c_id 492423664
# Analyzing site 95 of 100 sites, c_id 1911428877
# Analyzing site 96 of 100 sites, c_id 1366939490
# Analyzing site 97 of 100 sites, c_id 1007132094
# Analyzing site 98 of 100 sites, c_id 636891105
# Analyzing site 99 of 100 sites, c_id 140917090
# Analyzing site 100 of 100 sites, c_id 1994239929

# %% [markdown]
# # BATCH 2

# %%
batch = 2

# %%
summary = pd.DataFrame()
date_not_analyzed = []
date_successfully_analyzed = []
site_number = 1

for c_id in c_id_batch_2: 
    print('Analyzing site {} of 100 sites, c_id {}'.format(site_number, c_id))
    site_number += 1
    
    last_month_analyzed = 201907
    last_cid_analyzed = 0
    count_curtailment = 0
    total_energy_generation = 0
    total_tripping_curtailment = 0
    for date in date_list: 
#         print('Analyzing c_id {} date {} ...'.format(c_id, date))
        
        #filter D-PV time series data
        date_dt = dt.datetime.strptime(date, '%Y-%m-%d').date()
        month_analyzed = date[:4] + date [5:7]
#         print('Analyzing c_id {} month {} ...'.format(c_id, month_analyzed))
        
        if not month_analyzed == last_month_analyzed:
            site_id_filter = data[month_analyzed]['c_id'] == c_id
            data_certain_site = data[month_analyzed].loc[site_id_filter]
            last_month_analyzed = month_analyzed
            
        date_filter = data_certain_site['date'] == date_dt
        data_analyzed = data_certain_site.loc[date_filter]
        data_analyzed = data_analyzed.sort_index(ascending=True)

        #check tripping curtailment
        ac_cap = int(site_details.loc[site_details['c_id'] == c_id, 'ac_cap_w'])
        size_is_ok = file_processing.check_data_size(data_analyzed, ac_cap)
        
        if not size_is_ok:
#             print('Cannot analyze {} site on {} due to incomplete data.'.format(c_id, date))
            date_not_analyzed.append(date)
#             data_analyzed['power'].plot()
#             plt.show()
        else:
            date_successfully_analyzed.append(date)
            data_site, ac_cap, dc_cap, EFF_SYSTEM, inverter = vvar_curt.site_organize(c_id, site_details, data_analyzed, unique_cids)
            data_site = file_processing.resample_in_minute(data_site)
            
            if date in csd_list:
                is_clear_sky_day = True
            else:
                is_clear_sky_day = False
            
            tripping_response, tripping_curt_energy, estimation_method, data_site = tripping_curt.check_tripping_curtailment(is_clear_sky_day, c_id, data_site, unique_cids, ac_cap, site_details, date)    
            energy_generated, data_site = energy_calculation.check_energy_generated(data_site, date, is_clear_sky_day, tripping_curt_energy)
            
            total_energy_generation += energy_generated
            
            if tripping_curt_energy > 0:
                count_curtailment += 1
                total_tripping_curtailment += tripping_curt_energy
    
    #summarize result
    c_id_summary = pd.DataFrame({
            'c_id' : [c_id],
            'total_energy_generation (kWh)' : [total_energy_generation],
            'total_tripping_curtailment (kWh)' : [total_tripping_curtailment],
            'count curtailment (days)' : [count_curtailment],
            'total days (days)' : [len(date_list)]
        })
    
    summary = pd.concat([summary, c_id_summary])

summary.to_csv(file_path + r'/tripping_alldays_{}.csv'.format(batch), index = False)
# Out:
# Analyzing site 1 of 100 sites, c_id 1765463917
# Analyzing site 2 of 100 sites, c_id 362641176
# Analyzing site 3 of 100 sites, c_id 501296684
# Analyzing site 4 of 100 sites, c_id 728603657
# Analyzing site 5 of 100 sites, c_id 1754502986
# Analyzing site 6 of 100 sites, c_id 671978489
# Analyzing site 7 of 100 sites, c_id 977227615
# Analyzing site 8 of 100 sites, c_id 576609445
# Analyzing site 9 of 100 sites, c_id 1822597721
# Analyzing site 10 of 100 sites, c_id 849091584
# Analyzing site 11 of 100 sites, c_id 466930914
# Analyzing site 12 of 100 sites, c_id 1836936064
# Analyzing site 13 of 100 sites, c_id 1909120217
# Analyzing site 14 of 100 sites, c_id 982512371
# Analyzing site 15 of 100 sites, c_id 401305664
# Analyzing site 16 of 100 sites, c_id 1203715542
# Analyzing site 17 of 100 sites, c_id 1599337672
# Analyzing site 18 of 100 sites, c_id 811944521
# Analyzing site 19 of 100 sites, c_id 467236422
# Analyzing site 20 of 100 sites, c_id 1706723726
# Analyzing site 21 of 100 sites, c_id 1713456246
# Analyzing site 22 of 100 sites, c_id 1227622020
# Analyzing site 23 of 100 sites, c_id 957650704
# Analyzing site 24 of 100 sites, c_id 508137767
# Analyzing site 25 of 100 sites, c_id 1613420528
# Analyzing site 26 of 100 sites, c_id 1627208041
# Analyzing site 27 of 100 sites, c_id 1811443394
# Analyzing site 28 of 100 sites, c_id 1506524479
# Analyzing site 29 of 100 sites, c_id 39417171
# Analyzing site 30 of 100 sites, c_id 1990199606
# Analyzing site 31 of 100 sites, c_id 1147871946
# Analyzing site 32 of 100 sites, c_id 1004910241
# Analyzing site 33 of 100 sites, c_id 1511222604
# Analyzing site 34 of 100 sites, c_id 1790088427
# Analyzing site 35 of 100 sites, c_id 1637595819
# Analyzing site 36 of 100 sites, c_id 1905319041
# Analyzing site 37 of 100 sites, c_id 1528929295
# Analyzing site 38 of 100 sites, c_id 1475845036
# Analyzing site 39 of 100 sites, c_id 1477306557
# Analyzing site 40 of 100 sites, c_id 515338333
# Analyzing site 41 of 100 sites, c_id 1966494071
# Analyzing site 42 of 100 sites, c_id 1645355415
# Analyzing site 43 of 100 sites, c_id 1248734683
# Analyzing site 44 of 100 sites, c_id 1028074375
# Analyzing site 45 of 100 sites, c_id 1537359689
# Analyzing site 46 of 100 sites, c_id 900129773
# Analyzing site 47 of 100 sites, c_id 1038443096
# Analyzing site 48 of 100 sites, c_id 35889201
# Analyzing site 49 of 100 sites, c_id 187402380
# Analyzing site 50 of 100 sites, c_id 926511220
# Analyzing site 51 of 100 sites, c_id 72386722
# Analyzing site 52 of 100 sites, c_id 1532680669
# Analyzing site 53 of 100 sites, c_id 499746036
# Analyzing site 54 of 100 sites, c_id 1861085133
# Analyzing site 55 of 100 sites, c_id 2116899524
# Analyzing site 56 of 100 sites, c_id 1900529386
# Analyzing site 57 of 100 sites, c_id 179084449
# Analyzing site 58 of 100 sites, c_id 573014856
# Analyzing site 59 of 100 sites, c_id 405987583
# Analyzing site 60 of 100 sites, c_id 656226721
# Analyzing site 61 of 100 sites, c_id 1746053148
# Analyzing site 62 of 100 sites, c_id 1515029411
# Analyzing site 63 of 100 sites, c_id 1883049647
# Analyzing site 64 of 100 sites, c_id 1850954042
# Analyzing site 65 of 100 sites, c_id 1219654055
# Analyzing site 66 of 100 sites, c_id 2142161536
# Analyzing site 67 of 100 sites, c_id 325649316
# Analyzing site 68 of 100 sites, c_id 237758401
# Analyzing site 69 of 100 sites, c_id 1953610616
# Analyzing site 70 of 100 sites, c_id 1463962930
# Analyzing site 71 of 100 sites, c_id 2039776147
# Analyzing site 72 of 100 sites, c_id 715451692
# Analyzing site 73 of 100 sites, c_id 1924036325
# Analyzing site 74 of 100 sites, c_id 923664764
# Analyzing site 75 of 100 sites, c_id 1077053141
# Analyzing site 76 of 100 sites, c_id 186187676
# Analyzing site 77 of 100 sites, c_id 506285419
# Analyzing site 78 of 100 sites, c_id 285661416
# Analyzing site 79 of 100 sites, c_id 1446182021
# Analyzing site 80 of 100 sites, c_id 183707077
# Analyzing site 81 of 100 sites, c_id 1963671355
# Analyzing site 82 of 100 sites, c_id 1390125475
# Analyzing site 83 of 100 sites, c_id 1145410040
# Analyzing site 84 of 100 sites, c_id 2015386434
# Analyzing site 85 of 100 sites, c_id 748385210
# Analyzing site 86 of 100 sites, c_id 824725118
# Analyzing site 87 of 100 sites, c_id 1112354210
# Analyzing site 88 of 100 sites, c_id 298243910
# Analyzing site 89 of 100 sites, c_id 1779765110
# Analyzing site 90 of 100 sites, c_id 1017508702
# Analyzing site 91 of 100 sites, c_id 432573265
# Analyzing site 92 of 100 sites, c_id 417197174
# Analyzing site 93 of 100 sites, c_id 556100725
# Analyzing site 94 of 100 sites, c_id 622759379
# Analyzing site 95 of 100 sites, c_id 1106575099
# Analyzing site 96 of 100 sites, c_id 375408977
# Analyzing site 97 of 100 sites, c_id 1489744312
# Analyzing site 98 of 100 sites, c_id 1424993957
# Analyzing site 99 of 100 sites, c_id 814682996
# Analyzing site 100 of 100 sites, c_id 619732320

# %% [markdown]
# # BATCH 3

# %%
batch = 3

# %%
summary = pd.DataFrame()
date_not_analyzed = []
date_successfully_analyzed = []
site_number = 1

for c_id in c_id_batch_3: 
    print('Analyzing site {} of 100 sites, c_id {}'.format(site_number, c_id))
    site_number += 1
    
    last_month_analyzed = 201907
    last_cid_analyzed = 0
    count_curtailment = 0
    total_energy_generation = 0
    total_tripping_curtailment = 0
    for date in date_list: 
#         print('Analyzing c_id {} date {} ...'.format(c_id, date))
        
        #filter D-PV time series data
        date_dt = dt.datetime.strptime(date, '%Y-%m-%d').date()
        month_analyzed = date[:4] + date [5:7]
#         print('Analyzing c_id {} month {} ...'.format(c_id, month_analyzed))
        
        if not month_analyzed == last_month_analyzed:
            site_id_filter = data[month_analyzed]['c_id'] == c_id
            data_certain_site = data[month_analyzed].loc[site_id_filter]
            last_month_analyzed = month_analyzed
            
        date_filter = data_certain_site['date'] == date_dt
        data_analyzed = data_certain_site.loc[date_filter]
        data_analyzed = data_analyzed.sort_index(ascending=True)

        #check tripping curtailment
        ac_cap = int(site_details.loc[site_details['c_id'] == c_id, 'ac_cap_w'])
        size_is_ok = file_processing.check_data_size(data_analyzed, ac_cap)
        
        if not size_is_ok:
#             print('Cannot analyze {} site on {} due to incomplete data.'.format(c_id, date))
            date_not_analyzed.append(date)
#             data_analyzed['power'].plot()
#             plt.show()
        else:
            date_successfully_analyzed.append(date)
            data_site, ac_cap, dc_cap, EFF_SYSTEM, inverter = vvar_curt.site_organize(c_id, site_details, data_analyzed, unique_cids)
            data_site = file_processing.resample_in_minute(data_site)
            
            if date in csd_list:
                is_clear_sky_day = True
            else:
                is_clear_sky_day = False
            
            tripping_response, tripping_curt_energy, estimation_method, data_site = tripping_curt.check_tripping_curtailment(is_clear_sky_day, c_id, data_site, unique_cids, ac_cap, site_details, date)    
            energy_generated, data_site = energy_calculation.check_energy_generated(data_site, date, is_clear_sky_day, tripping_curt_energy)
            
            total_energy_generation += energy_generated
            
            if tripping_curt_energy > 0:
                count_curtailment += 1
                total_tripping_curtailment += tripping_curt_energy
    
    #summarize result
    c_id_summary = pd.DataFrame({
            'c_id' : [c_id],
            'total_energy_generation (kWh)' : [total_energy_generation],
            'total_tripping_curtailment (kWh)' : [total_tripping_curtailment],
            'count curtailment (days)' : [count_curtailment],
            'total days (days)' : [len(date_list)]
        })
    
    summary = pd.concat([summary, c_id_summary])

summary.to_csv(file_path + r'/tripping_alldays_{}.csv'.format(batch), index = False)
# Out:
# Analyzing site 1 of 100 sites, c_id 177405556
# Analyzing site 2 of 100 sites, c_id 59669332
# Analyzing site 3 of 100 sites, c_id 1690883528
# Analyzing site 4 of 100 sites, c_id 702120477
# Analyzing site 5 of 100 sites, c_id 97140845
# Analyzing site 6 of 100 sites, c_id 497516643
# Analyzing site 7 of 100 sites, c_id 1865614692
# Analyzing site 8 of 100 sites, c_id 1425948483
# Analyzing site 9 of 100 sites, c_id 58399862
# Analyzing site 10 of 100 sites, c_id 2995222
# Analyzing site 11 of 100 sites, c_id 2041574091
# Analyzing site 12 of 100 sites, c_id 460511237
# Analyzing site 13 of 100 sites, c_id 1760465917
# Analyzing site 14 of 100 sites, c_id 1002568637
# Analyzing site 15 of 100 sites, c_id 1489730840
# Analyzing site 16 of 100 sites, c_id 105687914
# Analyzing site 17 of 100 sites, c_id 1093529952
# Analyzing site 18 of 100 sites, c_id 427932258
# Analyzing site 19 of 100 sites, c_id 1722389076
# Analyzing site 20 of 100 sites, c_id 317767350
# Analyzing site 21 of 100 sites, c_id 522666364
# Analyzing site 22 of 100 sites, c_id 772730731
# Analyzing site 23 of 100 sites, c_id 349379266
# Analyzing site 24 of 100 sites, c_id 1274799482
# Analyzing site 25 of 100 sites, c_id 1305285980
# Analyzing site 26 of 100 sites, c_id 960498683
# Analyzing site 27 of 100 sites, c_id 188647262
# Analyzing site 28 of 100 sites, c_id 633166515
# Analyzing site 29 of 100 sites, c_id 253180398
# Analyzing site 30 of 100 sites, c_id 1659703205
# Analyzing site 31 of 100 sites, c_id 1606158999
# Analyzing site 32 of 100 sites, c_id 765528477
# Analyzing site 33 of 100 sites, c_id 587988963
# Analyzing site 34 of 100 sites, c_id 307069902
# Analyzing site 35 of 100 sites, c_id 6465663
# Analyzing site 36 of 100 sites, c_id 823271537
# Analyzing site 37 of 100 sites, c_id 1158626518
# Analyzing site 38 of 100 sites, c_id 954516763
# Analyzing site 39 of 100 sites, c_id 936808978
# Analyzing site 40 of 100 sites, c_id 2145391109
# Analyzing site 41 of 100 sites, c_id 1868533072
# Analyzing site 42 of 100 sites, c_id 1165442853
# Analyzing site 43 of 100 sites, c_id 166768109
# Analyzing site 44 of 100 sites, c_id 32497732
# Analyzing site 45 of 100 sites, c_id 122516627
# Analyzing site 46 of 100 sites, c_id 87496163
# Analyzing site 47 of 100 sites, c_id 192792497
# Analyzing site 48 of 100 sites, c_id 769724711
# Analyzing site 49 of 100 sites, c_id 166614887
# Analyzing site 50 of 100 sites, c_id 1406768264
# Analyzing site 51 of 100 sites, c_id 143071446
# Analyzing site 52 of 100 sites, c_id 2085909376
# Analyzing site 53 of 100 sites, c_id 2020330076
# Analyzing site 54 of 100 sites, c_id 65919370
# Analyzing site 55 of 100 sites, c_id 481355415
# Analyzing site 56 of 100 sites, c_id 1629486827
# Analyzing site 57 of 100 sites, c_id 655131985
# Analyzing site 58 of 100 sites, c_id 1254003935
# Analyzing site 59 of 100 sites, c_id 87228538
# Analyzing site 60 of 100 sites, c_id 494249660
# Analyzing site 61 of 100 sites, c_id 8366267
# Analyzing site 62 of 100 sites, c_id 2031907181
# Analyzing site 63 of 100 sites, c_id 791639184
# Analyzing site 64 of 100 sites, c_id 495057057
# Analyzing site 65 of 100 sites, c_id 1551349304
# Analyzing site 66 of 100 sites, c_id 455268757
# Analyzing site 67 of 100 sites, c_id 2130597181
# Analyzing site 68 of 100 sites, c_id 736617838
# Analyzing site 69 of 100 sites, c_id 302951762
# Analyzing site 70 of 100 sites, c_id 432468715
# Analyzing site 71 of 100 sites, c_id 1833008953
# Analyzing site 72 of 100 sites, c_id 1733245313
# Analyzing site 73 of 100 sites, c_id 495815101
# Analyzing site 74 of 100 sites, c_id 1443317220
# Analyzing site 75 of 100 sites, c_id 418583541
# Analyzing site 76 of 100 sites, c_id 1831940935
# Analyzing site 77 of 100 sites, c_id 11849250
# Analyzing site 78 of 100 sites, c_id 1357142821
# Analyzing site 79 of 100 sites, c_id 275184016
# Analyzing site 80 of 100 sites, c_id 1502333872
# Analyzing site 81 of 100 sites, c_id 1469982823
# Analyzing site 82 of 100 sites, c_id 1464371916
# Analyzing site 83 of 100 sites, c_id 548306365
# Analyzing site 84 of 100 sites, c_id 321888603
# Analyzing site 85 of 100 sites, c_id 2059286195
# Analyzing site 86 of 100 sites, c_id 830274244
# Analyzing site 87 of 100 sites, c_id 141138839
# Analyzing site 88 of 100 sites, c_id 1568818341
# Analyzing site 89 of 100 sites, c_id 862156377
# Analyzing site 90 of 100 sites, c_id 1065938166
# Analyzing site 91 of 100 sites, c_id 1632538235
# Analyzing site 92 of 100 sites, c_id 1053667170
# Analyzing site 93 of 100 sites, c_id 1076494630
# Analyzing site 94 of 100 sites, c_id 1967552706
# Analyzing site 95 of 100 sites, c_id 490255203
# Analyzing site 96 of 100 sites, c_id 1337085637
# Analyzing site 97 of 100 sites, c_id 1658280060
# Analyzing site 98 of 100 sites, c_id 1445534306
# Analyzing site 99 of 100 sites, c_id 1520040489
# Analyzing site 100 of 100 sites, c_id 945970002

# %% [markdown]
# # BATCH 4

# %%
batch = 4

# %%
summary = pd.DataFrame()
date_not_analyzed = []
date_successfully_analyzed = []
site_number = 1

for c_id in c_id_batch_4: 
    print('Analyzing site {} of 100 sites, c_id {}'.format(site_number, c_id))
    site_number += 1
    
    last_month_analyzed = 201907
    last_cid_analyzed = 0
    count_curtailment = 0
    total_energy_generation = 0
    total_tripping_curtailment = 0
    for date in date_list: 
#         print('Analyzing c_id {} date {} ...'.format(c_id, date))
        
        #filter D-PV time series data
        date_dt = dt.datetime.strptime(date, '%Y-%m-%d').date()
        month_analyzed = date[:4] + date [5:7]
#         print('Analyzing c_id {} month {} ...'.format(c_id, month_analyzed))
        
        if not month_analyzed == last_month_analyzed:
            site_id_filter = data[month_analyzed]['c_id'] == c_id
            data_certain_site = data[month_analyzed].loc[site_id_filter]
            last_month_analyzed = month_analyzed
            
        date_filter = data_certain_site['date'] == date_dt
        data_analyzed = data_certain_site.loc[date_filter]
        data_analyzed = data_analyzed.sort_index(ascending=True)

        #check tripping curtailment
        ac_cap = int(site_details.loc[site_details['c_id'] == c_id, 'ac_cap_w'])
        size_is_ok = file_processing.check_data_size(data_analyzed, ac_cap)
        
        if not size_is_ok:
#             print('Cannot analyze {} site on {} due to incomplete data.'.format(c_id, date))
            date_not_analyzed.append(date)
#             data_analyzed['power'].plot()
#             plt.show()
        else:
            date_successfully_analyzed.append(date)
            data_site, ac_cap, dc_cap, EFF_SYSTEM, inverter = vvar_curt.site_organize(c_id, site_details, data_analyzed, unique_cids)
            data_site = file_processing.resample_in_minute(data_site)
            
            if date in csd_list:
                is_clear_sky_day = True
            else:
                is_clear_sky_day = False
            
            tripping_response, tripping_curt_energy, estimation_method, data_site = tripping_curt.check_tripping_curtailment(is_clear_sky_day, c_id, data_site, unique_cids, ac_cap, site_details, date)    
            energy_generated, data_site = energy_calculation.check_energy_generated(data_site, date, is_clear_sky_day, tripping_curt_energy)
            
            total_energy_generation += energy_generated
            
            if tripping_curt_energy > 0:
                count_curtailment += 1
                total_tripping_curtailment += tripping_curt_energy
    
    #summarize result
    c_id_summary = pd.DataFrame({
            'c_id' : [c_id],
            'total_energy_generation (kWh)' : [total_energy_generation],
            'total_tripping_curtailment (kWh)' : [total_tripping_curtailment],
            'count curtailment (days)' : [count_curtailment],
            'total days (days)' : [len(date_list)]
        })
    
    summary = pd.concat([summary, c_id_summary])

summary.to_csv(file_path + r'/tripping_alldays_{}.csv'.format(batch), index = False)
# Out:
# Analyzing site 1 of 100 sites, c_id 1216561746
# Analyzing site 2 of 100 sites, c_id 164625127
# Analyzing site 3 of 100 sites, c_id 1926768907
# Analyzing site 4 of 100 sites, c_id 479577339
# Analyzing site 5 of 100 sites, c_id 1428393021
# Analyzing site 6 of 100 sites, c_id 1754924776
# Analyzing site 7 of 100 sites, c_id 2122979895
# Analyzing site 8 of 100 sites, c_id 941326991
# Analyzing site 9 of 100 sites, c_id 1238056675
# Analyzing site 10 of 100 sites, c_id 346565146
# Analyzing site 11 of 100 sites, c_id 284718553
# Analyzing site 12 of 100 sites, c_id 280027210
# Analyzing site 13 of 100 sites, c_id 1839636160
# Analyzing site 14 of 100 sites, c_id 1980046923
# Analyzing site 15 of 100 sites, c_id 369696407
# Analyzing site 16 of 100 sites, c_id 1460062907
# Analyzing site 17 of 100 sites, c_id 915410219
# Analyzing site 18 of 100 sites, c_id 1421859171
# Analyzing site 19 of 100 sites, c_id 1649995147
# Analyzing site 20 of 100 sites, c_id 1054247621
# Analyzing site 21 of 100 sites, c_id 628090576
# Analyzing site 22 of 100 sites, c_id 269285720
# Analyzing site 23 of 100 sites, c_id 1134323123
# Analyzing site 24 of 100 sites, c_id 1122684706
# Analyzing site 25 of 100 sites, c_id 1341927206
# Analyzing site 26 of 100 sites, c_id 1105174553
# Analyzing site 27 of 100 sites, c_id 466647987
# Analyzing site 28 of 100 sites, c_id 134896412
# Analyzing site 29 of 100 sites, c_id 1997816243
# Analyzing site 30 of 100 sites, c_id 929158790
# Analyzing site 31 of 100 sites, c_id 602764242
# Analyzing site 32 of 100 sites, c_id 1365659170
# Analyzing site 33 of 100 sites, c_id 1828269005
# Analyzing site 34 of 100 sites, c_id 1772238201
# Analyzing site 35 of 100 sites, c_id 1941443029
# Analyzing site 36 of 100 sites, c_id 479810032
# Analyzing site 37 of 100 sites, c_id 2072941613
# Analyzing site 38 of 100 sites, c_id 1618080873
# Analyzing site 39 of 100 sites, c_id 917876513
# Analyzing site 40 of 100 sites, c_id 641682872
# Analyzing site 41 of 100 sites, c_id 1902465915
# Analyzing site 42 of 100 sites, c_id 590576620
# Analyzing site 43 of 100 sites, c_id 902742197
# Analyzing site 44 of 100 sites, c_id 1888257763
# Analyzing site 45 of 100 sites, c_id 1898710649
# Analyzing site 46 of 100 sites, c_id 1109689296
# Analyzing site 47 of 100 sites, c_id 614770329
# Analyzing site 48 of 100 sites, c_id 1373354657
# Analyzing site 49 of 100 sites, c_id 1601564429
# Analyzing site 50 of 100 sites, c_id 1889457001
# Analyzing site 51 of 100 sites, c_id 379904777
# Analyzing site 52 of 100 sites, c_id 1228496975
# Analyzing site 53 of 100 sites, c_id 1266446943
# Analyzing site 54 of 100 sites, c_id 1687559437
# Analyzing site 55 of 100 sites, c_id 1313790654
# Analyzing site 56 of 100 sites, c_id 1835831701
# Analyzing site 57 of 100 sites, c_id 1248803494
# Analyzing site 58 of 100 sites, c_id 1045498135
# Analyzing site 59 of 100 sites, c_id 1317822057
# Analyzing site 60 of 100 sites, c_id 1736445593
# Analyzing site 61 of 100 sites, c_id 173654980
# Analyzing site 62 of 100 sites, c_id 1556557436
# Analyzing site 63 of 100 sites, c_id 502366235
# Analyzing site 64 of 100 sites, c_id 1981491157
# Analyzing site 65 of 100 sites, c_id 1976905687
# Analyzing site 66 of 100 sites, c_id 474178196
# Analyzing site 67 of 100 sites, c_id 891630340
# Analyzing site 68 of 100 sites, c_id 350830795
# Analyzing site 69 of 100 sites, c_id 1839398939
# Analyzing site 70 of 100 sites, c_id 1523415607
# Analyzing site 71 of 100 sites, c_id 226534958
# Analyzing site 72 of 100 sites, c_id 1171914822
# Analyzing site 73 of 100 sites, c_id 1580745757
# Analyzing site 74 of 100 sites, c_id 2091323801
# Analyzing site 75 of 100 sites, c_id 925171968
# Analyzing site 76 of 100 sites, c_id 328953515
# Analyzing site 77 of 100 sites, c_id 75601389
# Analyzing site 78 of 100 sites, c_id 700082593
# Analyzing site 79 of 100 sites, c_id 433152057
# Analyzing site 80 of 100 sites, c_id 337155131
# Analyzing site 81 of 100 sites, c_id 762317906
# Analyzing site 82 of 100 sites, c_id 1139751829
# Analyzing site 83 of 100 sites, c_id 676054389
# Analyzing site 84 of 100 sites, c_id 2098212820
# Analyzing site 85 of 100 sites, c_id 406963483
# Analyzing site 86 of 100 sites, c_id 362267093
# Analyzing site 87 of 100 sites, c_id 1664278908
# Analyzing site 88 of 100 sites, c_id 690649773
# Analyzing site 89 of 100 sites, c_id 1508371494
# Analyzing site 90 of 100 sites, c_id 1931150128
# Analyzing site 91 of 100 sites, c_id 1828350524
# Analyzing site 92 of 100 sites, c_id 723647467
# Analyzing site 93 of 100 sites, c_id 321084463
# Analyzing site 94 of 100 sites, c_id 1732469525
# Analyzing site 95 of 100 sites, c_id 1593107282
# Analyzing site 96 of 100 sites, c_id 902784592
# Analyzing site 97 of 100 sites, c_id 714546223
# Analyzing site 98 of 100 sites, c_id 804089919
# Analyzing site 99 of 100 sites, c_id 411782086
# Analyzing site 100 of 100 sites, c_id 1237836810

# %% [markdown]
# # BATCH 5

# %%
batch = 5

# %%
summary = pd.DataFrame()
date_not_analyzed = []
date_successfully_analyzed = []
site_number = 1

for c_id in c_id_batch_5: 
    print('Analyzing site {} of 100 sites, c_id {}'.format(site_number, c_id))
    site_number += 1
    
    last_month_analyzed = 201907
    last_cid_analyzed = 0
    count_curtailment = 0
    total_energy_generation = 0
    total_tripping_curtailment = 0
    for date in date_list: 
#         print('Analyzing c_id {} date {} ...'.format(c_id, date))
        
        #filter D-PV time series data
        date_dt = dt.datetime.strptime(date, '%Y-%m-%d').date()
        month_analyzed = date[:4] + date [5:7]
#         print('Analyzing c_id {} month {} ...'.format(c_id, month_analyzed))
        
        if not month_analyzed == last_month_analyzed:
            site_id_filter = data[month_analyzed]['c_id'] == c_id
            data_certain_site = data[month_analyzed].loc[site_id_filter]
            last_month_analyzed = month_analyzed
            
        date_filter = data_certain_site['date'] == date_dt
        data_analyzed = data_certain_site.loc[date_filter]
        data_analyzed = data_analyzed.sort_index(ascending=True)

        #check tripping curtailment
        ac_cap = int(site_details.loc[site_details['c_id'] == c_id, 'ac_cap_w'])
        size_is_ok = file_processing.check_data_size(data_analyzed, ac_cap)
        
        if not size_is_ok:
#             print('Cannot analyze {} site on {} due to incomplete data.'.format(c_id, date))
            date_not_analyzed.append(date)
#             data_analyzed['power'].plot()
#             plt.show()
        else:
            date_successfully_analyzed.append(date)
            data_site, ac_cap, dc_cap, EFF_SYSTEM, inverter = vvar_curt.site_organize(c_id, site_details, data_analyzed, unique_cids)
            data_site = file_processing.resample_in_minute(data_site)
            
            if date in csd_list:
                is_clear_sky_day = True
            else:
                is_clear_sky_day = False
            
            tripping_response, tripping_curt_energy, estimation_method, data_site = tripping_curt.check_tripping_curtailment(is_clear_sky_day, c_id, data_site, unique_cids, ac_cap, site_details, date)    
            energy_generated, data_site = energy_calculation.check_energy_generated(data_site, date, is_clear_sky_day, tripping_curt_energy)
            
            total_energy_generation += energy_generated
            
            if tripping_curt_energy > 0:
                count_curtailment += 1
                total_tripping_curtailment += tripping_curt_energy
    
    #summarize result
    c_id_summary = pd.DataFrame({
            'c_id' : [c_id],
            'total_energy_generation (kWh)' : [total_energy_generation],
            'total_tripping_curtailment (kWh)' : [total_tripping_curtailment],
            'count curtailment (days)' : [count_curtailment],
            'total days (days)' : [len(date_list)]
        })
    
    summary = pd.concat([summary, c_id_summary])

summary.to_csv(file_path + r'/tripping_alldays_{}.csv'.format(batch), index = False)

# %% [markdown]
# # COMBINE ALL RESULTS OF CSD

# %% [markdown]
# This is to combine some of the results in the previous section that is done in seperate times. Should not be needed if the above section is run only once for all sites.

# %%
summary_1 = pd.read_csv(file_path + r'/tripping_csd_1.csv')
summary_2 = pd.read_csv(file_path + r'/tripping_csd_2.csv')
summary_3 = pd.read_csv(file_path + r'/tripping_csd_3.csv')
summary_4 = pd.read_csv(file_path + r'/tripping_csd_4.csv')
summary_5 = pd.read_csv(file_path + r'/tripping_csd_5.csv')

# %%
summary = pd.concat([summary_1, summary_2, summary_3, summary_4, summary_5])

# %%
summary['percentage_of_generation_lost'] = summary['total_tripping_curtailment (kWh)'] / summary['total_energy_generation (kWh)'] * 100
summary['proportion of days with curtailment'] = summary['count curtailment (days)'] / summary['total days (days)'] * 100
summary.sort_values(by = 'percentage_of_generation_lost', ascending = False, inplace = True)
summary.reset_index(drop = True, inplace = True)
summary['proportion_of_sites'] = summary.index/(len(summary)-1) * 100

# %%
summary
# Out:
#            c_id  total_energy_generation (kWh)  \
# 0    1732727321                    1070.806555
# 1    1317822057                    1288.073679
# 2     441066515                    1308.479307
# 3    2084803628                    1326.827498
# 4     939510347                    1347.940476
# ..          ...                            ...
# 495  1542012877                     840.518182
# 496  1803391106                    1074.171921
# 497  1593107282                     574.400725
# 498   573014856                     617.799263
# 499   432573265                    1565.552580
#
#      total_tripping_curtailment (kWh)  count curtailment (days)  \
# 0                          287.597705                        52
# 1                          196.663373                        43
# 2                          111.952332                        43
# 3                          109.123178                        36
# 4                          109.630479                        30
# ..                                ...                       ...
# 495                          0.000000                         0
# 496                          0.000000                         0
# 497                          0.000000                         0
# 498                          0.000000                         0
# 499                          0.000000                         0
#
#      total days (days)  percentage_of_generation_lost  \
# 0                   54                      26.858045
# 1                   54                      15.268022
# 2                   54                       8.555912
# 3                   54                       8.224368
# 4                   54                       8.133184
# ..                 ...                            ...
# 495                 54                       0.000000
# 496                 54                       0.000000
# 497                 54                       0.000000
# 498                 54                       0.000000
# 499                 54                       0.000000
#
#      proportion of days with curtailment  proportion_of_sites
# 0                              96.296296             0.000000
# 1                              79.629630             0.200401
# 2                              79.629630             0.400802
# 3                              66.666667             0.601202
# 4                              55.555556             0.801603
# ..                                   ...                  ...
# 495                             0.000000            99.198397
# 496                             0.000000            99.398798
# 497                             0.000000            99.599198
# 498                             0.000000            99.799599
# 499                             0.000000           100.000000
#
# [500 rows x 8 columns]

# %%
summary.to_csv(file_path + r'/tripping_csd_summary_all.csv', index = False)

# %% [markdown]
# # COMBINE ALL RESULTS OF ALL DAYS

# %% [markdown]
# This is to combine some of the results in the previous section that is done in seperate times. Should not be needed if the above section is run only once for all sites.

# %%
summary_1 = pd.read_csv(file_path + r'/tripping_alldays_1.csv')
summary_2 = pd.read_csv(file_path + r'/tripping_alldays_2.csv')
summary_3 = pd.read_csv(file_path + r'/tripping_alldays_3.csv')
summary_4 = pd.read_csv(file_path + r'/tripping_alldays_4.csv')
summary_5 = pd.read_csv(file_path + r'/tripping_alldays_5.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 summary_1 = pd.read_csv(file_path + r'/tripping_alldays_1.csv')
#       2 summary_2 = pd.read_csv(file_path + r'/tripping_alldays_2.csv')
#       3 summary_3 = pd.read_csv(file_path + r'/tripping_alldays_3.csv')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/samhan/Downloads/data/tripping_alldays_1.csv'

# %%
summary = pd.concat([summary_1, summary_2, summary_3, summary_4, summary_5])

# %%
summary['percentage_of_generation_lost'] = summary['total_tripping_curtailment (kWh)'] / summary['total_energy_generation (kWh)'] * 100
summary['proportion of days with curtailment'] = summary['count curtailment (days)'] / summary['total days (days)'] * 100
summary.sort_values(by = 'percentage_of_generation_lost', ascending = False, inplace = True)
summary.reset_index(drop = True, inplace = True)
summary['proportion_of_sites'] = summary.index/(len(summary)-1) * 100

# %%
summary.to_csv(file_path + r'/tripping_alldays_summary_all.csv', index = False)

# %% [markdown]
# # VISUALIZATION SIMILAR TO FIGURE 14

# %%
#file_path = r"/Users/samhan/Downloads/data" #for running in Samhan's laptop
file_path = r"C:\Users\samha\Documents\CANVAS\data" #for running in TETB CEEM09 computer

summary = pd.read_csv(file_path +r'/tripping_csd_summary_all.csv')

# %%
summary
# Out:
#            c_id  total_energy_generation (kWh)  \
# 0    1732727321                    1070.806555
# 1    1317822057                    1288.073679
# 2     441066515                    1308.479307
# 3    2084803628                    1326.827498
# 4     939510347                    1347.940476
# ..          ...                            ...
# 495  1542012877                     840.518182
# 496  1803391106                    1074.171921
# 497  1593107282                     574.400725
# 498   573014856                     617.799263
# 499   432573265                    1565.552580
#
#      total_tripping_curtailment (kWh)  count curtailment (days)  \
# 0                          287.597705                        52
# 1                          196.663373                        43
# 2                          111.952332                        43
# 3                          109.123178                        36
# 4                          109.630479                        30
# ..                                ...                       ...
# 495                          0.000000                         0
# 496                          0.000000                         0
# 497                          0.000000                         0
# 498                          0.000000                         0
# 499                          0.000000                         0
#
#      total days (days)  percentage_of_generation_lost  \
# 0                   54                      26.858045
# 1                   54                      15.268022
# 2                   54                       8.555912
# 3                   54                       8.224368
# 4                   54                       8.133184
# ..                 ...                            ...
# 495                 54                       0.000000
# 496                 54                       0.000000
# 497                 54                       0.000000
# 498                 54                       0.000000
# 499                 54                       0.000000
#
#      proportion of days with curtailment  proportion_of_sites
# 0                              96.296296             0.000000
# 1                              79.629630             0.200401
# 2                              79.629630             0.400802
# 3                              66.666667             0.601202
# 4                              55.555556             0.801603
# ..                                   ...                  ...
# 495                             0.000000            99.198397
# 496                             0.000000            99.398798
# 497                             0.000000            99.599198
# 498                             0.000000            99.799599
# 499                             0.000000           100.000000
#
# [500 rows x 8 columns]

# %%
fig, ax1 = plt.subplots()
fig.set_size_inches(18, 10)

ax1.scatter(summary['proportion_of_sites'], summary["percentage_of_generation_lost"], color = 'b', 
            label = 'Percentage generation lost')

ax1.set_xlabel('Proportion of sites', **fontdict)
ax1.set_ylabel('Percentage of generation lost per site', **fontdict)

ax1.set_xticks([0, 20, 40, 60, 80, 100])
ax1.set_xticklabels(['0 %', '20 %', '40 %', '60 %', '80 %', '100 %'], **fontdict)
ax1.set_ylim(0, 25);
ax1.set_yticks([0, 5, 10, 15, 20, 25])
ax1.set_yticklabels(['0 %', '5 %', '10 %', '15 %', '20 %', '25 %'], **fontdict)
ax1.legend(loc = 9, prop={'size': 15})

ax2 = ax1.twinx()
ax2.scatter(summary['proportion_of_sites'], summary['proportion of days with curtailment'], color='r',
           label = 'Proportion of days with some curtailment')
ax2.set_ylabel('Proportion of days with some curtailment', **fontdict)
ax2.set_yticks([0, 20, 40, 60, 80, 100])
ax2.set_yticklabels(['0 %', '20 %', '40 %', '60 %', '80 %', '100 %'], **fontdict)
ax2.set_ylim(0, 100);
ax2.legend(loc = 0, prop={'size': 15})

plt.show()

# %% [markdown]
# # UPDATING SPREADSHEET

# %%
spreadsheet_before = pd.read_excel(file_path + r'/SolA Curtailment Summary_Final_trippingcsd.xlsx')
#spreadsheet_before.drop(columns = 'Unnamed: 0', inplace = True)

new_data = summary[['c_id', 'total_energy_generation (kWh)', 'total_tripping_curtailment (kWh)']].copy()
new_data.rename(columns={
    "total_energy_generation (kWh)": "total_energy_generation_alldays (kWh)",
    "total_tripping_curtailment (kWh)": "total_tripping_curtailment_alldays (kWh)"}, inplace = True)

spreadsheet_after = pd.merge(spreadsheet_before, new_data, left_on = 'c_id', right_on = 'c_id', how = 'inner')

# %%
spreadsheet_after.to_excel(file_path + r'/SolA Curtailment Summary_Final_trippingalldays.xlsx', index = False)

# %% [markdown]
# # MESSY BELOW
