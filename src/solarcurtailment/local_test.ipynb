# %%
import solarcurtailment
# Out:
# C:\Users\samha\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
#file_path = r"/Users/samhan/Downloads/data" #this is for running in Samhan's laptop
file_path = r"C:\Users\samha\Documents\CANVAS\data" #for running in TETB CEEM09 computer

for i in [1, 11, 14, 4, 5, 8, 9]: 
    sample_number = i
    print('Analyzing sample number {}'.format(i))
    data_file = '/data_sample_{}.csv'.format(sample_number)
    ghi_file = '/ghi_sample_{}.csv'.format(sample_number)

    solarcurtailment.compute(file_path, data_file, ghi_file)
# Out:
# Analyzing sample number 1
# C:\Users\samha\Documents\CANVAS\CANVAS-Open-Source\src\solarcurtailment\tripping_curt.py:756: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_df['non_clear_sky_day_flag'] = 1
# C:\Users\samha\Documents\CANVAS\CANVAS-Open-Source\src\solarcurtailment\tripping_curt.py:790: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['polynomial_fit'] = z[0]*test['time_in_seconds']*test['time_in_seconds'] + \
# C:\Users\samha\Documents\CANVAS\CANVAS-Open-Source\src\solarcurtailment\tripping_curt.py:799: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['ones'] = 1
# C:\Users\samha\Documents\CANVAS\CANVAS-Open-Source\src\solarcurtailment\tripping_curt.py:802: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   m,c = np.linalg.lstsq(A,y)[0]
# C:\Users\samha\Documents\CANVAS\CANVAS-Open-Source\src\solarcurtailment\tripping_curt.py:803: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['y_line'] = c + m*test['cf']
# C:\Users\samha\Documents\CANVAS\CANVAS-Open-Source\src\solarcurtailment\tripping_curt.py:807: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['residuals'] = test['polynomial_fit'] - test['y_line']
# C:\Users\samha\Documents\CANVAS\CANVAS-Open-Source\src\solarcurtailment\tripping_curt.py:815: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_filtered['polynomial_fit'] = z[0]*test_filtered['time_in_seconds']*test_filtered['time_in_seconds'] + \
#          c_id        date  clear sky day  energy generated (kWh)  \
# 0  1317822057  2019-09-03          False               11.227399
#
#    expected energy generated (kWh) estimation method tripping response  \
# 0                        16.042172            Linear               Yes
#
#    tripping curtailment (kWh) V-VAr response  V-VAr curtailment (kWh)  \
# 0                    4.814773            Yes                      0.0
#
#                           V-Watt response  V-Watt curtailment (kWh)
# 0  Inconclusive due to non clear sky day.                       NaN
# Analyzing sample number 11
# C:\Users\samha\Documents\CANVAS\CANVAS-Open-Source\src\solarcurtailment\tripping_curt.py:754: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_df['non_clear_sky_day_flag'] = 0
# C:\Users\samha\Documents\CANVAS\CANVAS-Open-Source\src\solarcurtailment\tripping_curt.py:790: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['polynomial_fit'] = z[0]*test['time_in_seconds']*test['time_in_seconds'] + \
# C:\Users\samha\Documents\CANVAS\CANVAS-Open-Source\src\solarcurtailment\tripping_curt.py:799: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['ones'] = 1
# C:\Users\samha\Documents\CANVAS\CANVAS-Open-Source\src\solarcurtailment\tripping_curt.py:802: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   m,c = np.linalg.lstsq(A,y)[0]
# C:\Users\samha\Documents\CANVAS\CANVAS-Open-Source\src\solarcurtailment\tripping_curt.py:803: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['y_line'] = c + m*test['cf']
# C:\Users\samha\Documents\CANVAS\CANVAS-Open-Source\src\solarcurtailment\tripping_curt.py:807: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['residuals'] = test['polynomial_fit'] - test['y_line']
# C:\Users\samha\Documents\CANVAS\CANVAS-Open-Source\src\solarcurtailment\tripping_curt.py:815: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_filtered['polynomial_fit'] = z[0]*test_filtered['time_in_seconds']*test_filtered['time_in_seconds'] + \
#          c_id        date  clear sky day  energy generated (kWh)  \
# 0  2084803628  2020-01-17           True               28.463915
#
#    expected energy generated (kWh) estimation method tripping response  \
# 0                        33.126945           Polyfit               Yes
#
#    tripping curtailment (kWh) V-VAr response  V-VAr curtailment (kWh)  \
# 0                     4.66303            Yes                      0.0
#
#   V-Watt response  V-Watt curtailment (kWh)
# 0            None                         0
# Analyzing sample number 14
#         c_id        date  clear sky day  energy generated (kWh)  \
# 0  173654980  2020-01-17           True               41.922012
#
#    expected energy generated (kWh) estimation method tripping response  \
# 0                              NaN           Polyfit              None
#
#    tripping curtailment (kWh) V-VAr response  V-VAr curtailment (kWh)  \
# 0                           0            Yes                 3.172943
#
#                                 V-Watt response  V-Watt curtailment (kWh)
# 0  Inconclusive due to insufficient data points                       NaN
# Analyzing sample number 4
#          c_id        date  clear sky day  energy generated (kWh)  \
# 0  1165442853  2020-04-13           True               31.951955
#
#    expected energy generated (kWh) estimation method tripping response  \
# 0                        36.583436           Polyfit              None
#
#    tripping curtailment (kWh) V-VAr response  V-VAr curtailment (kWh)  \
# 0                           0            Yes                      0.0
#
#   V-Watt response  V-Watt curtailment (kWh)
# 0             Yes                  4.631481
# Analyzing sample number 5
# Cannot analyze this sample due to incomplete data.
# Analyzing sample number 8
#          c_id        date  clear sky day  energy generated (kWh)  \
# 0  1700492033  2020-01-17           True               22.965787
#
#    expected energy generated (kWh) estimation method tripping response  \
# 0                        23.011685           Polyfit              None
#
#    tripping curtailment (kWh) V-VAr response  V-VAr curtailment (kWh)  \
# 0                           0            Yes                 0.045898
#
#   V-Watt response  V-Watt curtailment (kWh)
# 0            None                         0
# Analyzing sample number 9
#         c_id        date  clear sky day  energy generated (kWh)  \
# 0  389622988  2020-01-17           True               34.867516
#
#    expected energy generated (kWh) estimation method tripping response  \
# 0                        34.867516           Polyfit              None
#
#    tripping curtailment (kWh) V-VAr response  V-VAr curtailment (kWh)  \
# 0                           0            Yes                      0.0
#
#   V-Watt response  V-Watt curtailment (kWh)
# 0            None                         0
